# %% [markdown]
# # Using nn module to create simple neural networ

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %% [markdown]
# # Data set

# %%
df = pd.read_csv('data/breast-cancer.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.drop(columns=('id'),inplace=True)

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
x_train,x_test,y_train,y_test = train_test_split(df.iloc[: ,1:],df.iloc[:,:1],random_state=42,test_size=.25)

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
scaler = StandardScaler()
encoder = LabelEncoder()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)
# Out:
# /home/hamza/Desktop/pytorch/venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:120: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/hamza/Desktop/pytorch/venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:139: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
# Out:
# numpy.ndarray

# %%
x_test_tensor = torch.tensor(x_test,dtype=torch.float32)
x_train_tensor = torch.tensor(x_train,dtype=torch.float32)

y_train_tensor = torch.tensor(y_train,dtype=torch.float32)
y_test_tesnor = torch.tensor(y_test,dtype=torch.float32)

# %% [markdown]
# ## Modle

# %%
class SimpleNN(nn.Module):
    def __init__(self,num_features):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(num_features,10),
            nn.ReLU(),
            nn.Linear(10,8),
            nn.ReLU(),
            nn.Linear(8,5),
            nn.ReLU(),
            nn.Linear(5,2),
            nn.ReLU(),
            nn.Linear(2,1),
            nn.Sigmoid()
        )

    def forward(self,x):
        return self.network(x)

# %%
model = SimpleNN(x_train_tensor.shape[1])

# %%
loss_fn = nn.BCELoss()

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.0001)

# %%
x_train_tensor.shape
# Out:
# torch.Size([426, 30])

# %%
for epoch in range(1,101):
    
    y_pred = model(x_train_tensor)

    y_pred = y_pred.view(-1) 
    loss = loss_fn(y_pred,y_train_tensor)
    if epoch % 10==0:
        print(f'Epoch {epoch}, Loss: {loss.item():.4f}')
    
    ## updating parameters

    # clearing gradient
    optimizer.zero_grad()

    # backpropargation
    loss.backward()

    # updating
    optimizer.step()
# Out:
# Epoch 10, Loss: 0.6616
# Epoch 20, Loss: 0.6616
# Epoch 30, Loss: 0.6616
# Epoch 40, Loss: 0.6616
# Epoch 50, Loss: 0.6615
# Epoch 60, Loss: 0.6615
# Epoch 70, Loss: 0.6615
# Epoch 80, Loss: 0.6615
# Epoch 90, Loss: 0.6615
# Epoch 100, Loss: 0.6615
