# %% [markdown]
# # Pretrained MODEL in pytorch

# %% [markdown]
# ## WrokFlow

# %% [markdown]
#     1.Load DataSet using(DataLoader)
#     2.Download pretrained Model
#     3.remove classifier
#     4.get the images embedings in vector form
#
# i will use efficentsNet pretrained model (using torchvision)
